# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 777

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_des = city_weather["weather"][0]['main']    
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "City_weather":city_des})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mount gambier
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 1 | imbituba
# Processing Record 6 of Set 1 | ridgecrest
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | kolimvari
# City not found. Skipping...
# Processing Record 9 of Set 1 | talgar
# Processing Record 10 of Set 1 | kitimat
# Processing Record 11 of Set 1 | sabang
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | sao jose da coroa grande
# Processing Record 14 of Set 1 | englehart
# Processing Record 15 of Set 1 | trairi
# Processing Record 16 of Set 1 | road town
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | mineiros
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | paamiut
# Processing Record 22 of Set 1 | chilca
# Processing Record 23 of Set 1 | fairbanks
# Processing Record 24 of Set 1 | nhulunbuy
# Processing Record 25 of Set 1 | arrecife
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | nabire
# Processing Record 28 of Set 1 | bekovo
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | hamilton
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | east london
# Processing Record 33 of Set 1 | half moon bay
# Processing Record 34 of Set 1 | carbonia
# Processing Record 35 of Set 1 | alyangula
# Processing Record 36 of Set 1 | tiksi
# Processing Record 37 of Set 1 | revda
# Processing Record 38 of Set 1 | ribeira grande
# Processing Record 39 of Set 1 | amursk
# Processing Record 40 of Set 1 | norman wells
# Processing Record 41 of Set 1 | bethel
# Processing Record 42 of Set 1 | sao felix do xingu
# Processing Record 43 of Set 1 | weyburn
# Processing Record 44 of Set 1 | sabha
# Processing Record 45 of Set 1 | mount pleasant
# Processing Record 46 of Set 1 | saint-francois
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | khatanga
# Processing Record 49 of Set 1 | mahebourg
# Processing Record 50 of Set 1 | oeiras do para
# Processing Record 1 of Set 2 | bodden town
# Processing Record 2 of Set 2 | arraial do cabo
# Processing Record 3 of Set 2 | mimongo
# Processing Record 4 of Set 2 | warrington
# Processing Record 5 of Set 2 | catalina
# Processing Record 6 of Set 2 | svetlogorsk
# Processing Record 7 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 8 of Set 2 | chamba
# Processing Record 9 of Set 2 | seoul
# Processing Record 10 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 2 | ippy
# Processing Record 12 of Set 2 | mattru
# Processing Record 13 of Set 2 | san juan
# Processing Record 14 of Set 2 | mantua
# Processing Record 15 of Set 2 | port hardy
# Processing Record 16 of Set 2 | touros
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | coquimbo
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | torbay
# Processing Record 21 of Set 2 | tsaratanana
# Processing Record 22 of Set 2 | nuuk
# Processing Record 23 of Set 2 | yenangyaung
# Processing Record 24 of Set 2 | sodertalje
# City not found. Skipping...
# Processing Record 25 of Set 2 | ushuaia
# Processing Record 26 of Set 2 | makakilo city
# Processing Record 27 of Set 2 | morant bay
# Processing Record 28 of Set 2 | ostrovnoy
# Processing Record 29 of Set 2 | dunedin
# Processing Record 30 of Set 2 | muravlenko
# Processing Record 31 of Set 2 | sola
# Processing Record 32 of Set 2 | kedrovyy
# Processing Record 33 of Set 2 | esperance
# Processing Record 34 of Set 2 | port lincoln
# Processing Record 35 of Set 2 | upernavik
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | albany
# Processing Record 38 of Set 2 | nikolskoye
# Processing Record 39 of Set 2 | pozoblanco
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | kahului
# Processing Record 42 of Set 2 | cherskiy
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | geraldton
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 | komsomolskiy
# Processing Record 47 of Set 2 | plum
# Processing Record 48 of Set 2 | sechura
# Processing Record 49 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 2 | ambilobe
# Processing Record 1 of Set 3 | hohhot
# Processing Record 2 of Set 3 | coxim
# Processing Record 3 of Set 3 | acari
# Processing Record 4 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 3 | kenai
# Processing Record 6 of Set 3 | faanui
# Processing Record 7 of Set 3 | oktyabrskiy
# Processing Record 8 of Set 3 | zhigansk
# Processing Record 9 of Set 3 | kapaa
# Processing Record 10 of Set 3 | lasa
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | flin flon
# Processing Record 13 of Set 3 | pangnirtung
# Processing Record 14 of Set 3 | naze
# Processing Record 15 of Set 3 | punta arenas
# Processing Record 16 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 3 | narsaq
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | majene
# Processing Record 20 of Set 3 | isiro
# Processing Record 21 of Set 3 | taoudenni
# Processing Record 22 of Set 3 | ambon
# Processing Record 23 of Set 3 | nanlong
# Processing Record 24 of Set 3 | tessalit
# Processing Record 25 of Set 3 | halifax
# Processing Record 26 of Set 3 | gorkovskoye
# City not found. Skipping...
# Processing Record 27 of Set 3 | hermanus
# Processing Record 28 of Set 3 | yerbogachen
# Processing Record 29 of Set 3 | dongsheng
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | saint george
# Processing Record 32 of Set 3 | lompoc
# Processing Record 33 of Set 3 | kruisfontein
# Processing Record 34 of Set 3 | hualmay
# Processing Record 35 of Set 3 | katobu
# Processing Record 36 of Set 3 | new norfolk
# Processing Record 37 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 3 | camacari
# Processing Record 39 of Set 3 | asau
# Processing Record 40 of Set 3 | cermik
# Processing Record 41 of Set 3 | leh
# Processing Record 42 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 3 | manakara
# Processing Record 44 of Set 3 | salamiyah
# Processing Record 45 of Set 3 | morros
# Processing Record 46 of Set 3 | bilma
# Processing Record 47 of Set 3 | buena vista
# Processing Record 48 of Set 3 | bengkulu
# Processing Record 49 of Set 3 | wladyslawowo
# Processing Record 50 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 4 | atbasar
# Processing Record 2 of Set 4 | dong hoi
# Processing Record 3 of Set 4 | leningradskiy
# Processing Record 4 of Set 4 | tabuk
# Processing Record 5 of Set 4 | manuk mangkaw
# Processing Record 6 of Set 4 | edd
# Processing Record 7 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 8 of Set 4 | kavieng
# Processing Record 9 of Set 4 | prachin buri
# Processing Record 10 of Set 4 | chokurdakh
# Processing Record 11 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 4 | yingcheng
# Processing Record 13 of Set 4 | iqaluit
# Processing Record 14 of Set 4 | sao joao da barra
# Processing Record 15 of Set 4 | ushtobe
# Processing Record 16 of Set 4 | severo-kurilsk
# Processing Record 17 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 4 | castro
# Processing Record 19 of Set 4 | katsuura
# Processing Record 20 of Set 4 | karratha
# Processing Record 21 of Set 4 | alice springs
# Processing Record 22 of Set 4 | zharkent
# Processing Record 23 of Set 4 | hithadhoo
# Processing Record 24 of Set 4 | mar del plata
# Processing Record 25 of Set 4 | moerai
# Processing Record 26 of Set 4 | bireun
# Processing Record 27 of Set 4 | bintulu
# Processing Record 28 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 4 | gopalganj
# Processing Record 30 of Set 4 | aksu
# Processing Record 31 of Set 4 | meulaboh
# Processing Record 32 of Set 4 | port elizabeth
# Processing Record 33 of Set 4 | vila franca do campo
# Processing Record 34 of Set 4 | dingle
# Processing Record 35 of Set 4 | bredasdorp
# Processing Record 36 of Set 4 | igrim
# Processing Record 37 of Set 4 | mareeba
# Processing Record 38 of Set 4 | simao
# Processing Record 39 of Set 4 | yar-sale
# Processing Record 40 of Set 4 | bluff
# Processing Record 41 of Set 4 | jujuy
# City not found. Skipping...
# Processing Record 42 of Set 4 | sao filipe
# Processing Record 43 of Set 4 | aitape
# Processing Record 44 of Set 4 | yulara
# Processing Record 45 of Set 4 | kiruna
# Processing Record 46 of Set 4 | olafsvik
# Processing Record 47 of Set 4 | lucea
# Processing Record 48 of Set 4 | chapais
# Processing Record 49 of Set 4 | kaitangata
# Processing Record 50 of Set 4 | kapustin yar
# Processing Record 1 of Set 5 | hovd
# Processing Record 2 of Set 5 | san cristobal
# Processing Record 3 of Set 5 | tanout
# Processing Record 4 of Set 5 | bereda
# Processing Record 5 of Set 5 | avarua
# Processing Record 6 of Set 5 | mecca
# Processing Record 7 of Set 5 | labuhan
# Processing Record 8 of Set 5 | sitka
# Processing Record 9 of Set 5 | chuy
# Processing Record 10 of Set 5 | kulhudhuffushi
# Processing Record 11 of Set 5 | cidreira
# Processing Record 12 of Set 5 | bambous virieux
# Processing Record 13 of Set 5 | wuda
# Processing Record 14 of Set 5 | vardo
# Processing Record 15 of Set 5 | pevek
# Processing Record 16 of Set 5 | oriental
# Processing Record 17 of Set 5 | nzerekore
# Processing Record 18 of Set 5 | shimoda
# Processing Record 19 of Set 5 | kindia
# Processing Record 20 of Set 5 | lavrentiya
# Processing Record 21 of Set 5 | mkushi
# Processing Record 22 of Set 5 | hurghada
# Processing Record 23 of Set 5 | luanda
# Processing Record 24 of Set 5 | hobyo
# Processing Record 25 of Set 5 | souillac
# Processing Record 26 of Set 5 | batagay-alyta
# Processing Record 27 of Set 5 | togur
# Processing Record 28 of Set 5 | baie-comeau
# Processing Record 29 of Set 5 | sijunjung
# Processing Record 30 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 31 of Set 5 | coihaique
# Processing Record 32 of Set 5 | ilek
# Processing Record 33 of Set 5 | luderitz
# Processing Record 34 of Set 5 | tuktoyaktuk
# Processing Record 35 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 5 | hastings
# Processing Record 37 of Set 5 | ponta do sol
# Processing Record 38 of Set 5 | atar
# Processing Record 39 of Set 5 | yemelyanovo
# Processing Record 40 of Set 5 | emba
# Processing Record 41 of Set 5 | georgetown
# Processing Record 42 of Set 5 | dwarka
# Processing Record 43 of Set 5 | mbandaka
# Processing Record 44 of Set 5 | wucheng
# Processing Record 45 of Set 5 | kununurra
# Processing Record 46 of Set 5 | jahrom
# City not found. Skipping...
# Processing Record 47 of Set 5 | kautokeino
# Processing Record 48 of Set 5 | bondo
# Processing Record 49 of Set 5 | catamarca
# Processing Record 50 of Set 5 | lorengau
# Processing Record 1 of Set 6 | thompson
# Processing Record 2 of Set 6 | kollam
# Processing Record 3 of Set 6 | crepy-en-valois
# Processing Record 4 of Set 6 | andenes
# Processing Record 5 of Set 6 | la ronge
# Processing Record 6 of Set 6 | richards bay
# Processing Record 7 of Set 6 | frankfurt
# Processing Record 8 of Set 6 | nishihara
# Processing Record 9 of Set 6 | trois-pistoles
# City not found. Skipping...
# Processing Record 10 of Set 6 | rocha
# Processing Record 11 of Set 6 | rio claro
# Processing Record 12 of Set 6 | mastic beach
# Processing Record 13 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 6 | alofi
# Processing Record 15 of Set 6 | adre
# Processing Record 16 of Set 6 | kuryk
# Processing Record 17 of Set 6 | mayo
# Processing Record 18 of Set 6 | dalvik
# Processing Record 19 of Set 6 | khanu woralaksaburi
# Processing Record 20 of Set 6 | tukrah
# Processing Record 21 of Set 6 | bugiri
# Processing Record 22 of Set 6 | wawa
# Processing Record 23 of Set 6 | tilichiki
# Processing Record 24 of Set 6 | grand forks
# Processing Record 25 of Set 6 | manokwari
# Processing Record 26 of Set 6 | killin
# Processing Record 27 of Set 6 | muros
# Processing Record 28 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 6 | nome
# Processing Record 30 of Set 6 | marsa matruh
# Processing Record 31 of Set 6 | mapiripan
# Processing Record 32 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 33 of Set 6 | sol-iletsk
# Processing Record 34 of Set 6 | flinders
# Processing Record 35 of Set 6 | poum
# Processing Record 36 of Set 6 | dunkwa
# Processing Record 37 of Set 6 | lata
# Processing Record 38 of Set 6 | riyadh
# Processing Record 39 of Set 6 | lagoa
# Processing Record 40 of Set 6 | juifang
# City not found. Skipping...
# Processing Record 41 of Set 6 | beruni
# City not found. Skipping...
# Processing Record 42 of Set 6 | tura
# Processing Record 43 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 6 | nizhniy kuranakh
# Processing Record 45 of Set 6 | longyearbyen
# Processing Record 46 of Set 6 | beloha
# Processing Record 47 of Set 6 | nangomba
# Processing Record 48 of Set 6 | tumaco
# Processing Record 49 of Set 6 | alta floresta
# Processing Record 50 of Set 6 | tateyama
# Processing Record 1 of Set 7 | buala
# Processing Record 2 of Set 7 | lewisburg
# Processing Record 3 of Set 7 | bathurst
# Processing Record 4 of Set 7 | san miguel
# Processing Record 5 of Set 7 | vao
# Processing Record 6 of Set 7 | gorontalo
# Processing Record 7 of Set 7 | preobrazheniye
# Processing Record 8 of Set 7 | marigot
# Processing Record 9 of Set 7 | itarema
# Processing Record 10 of Set 7 | kendari
# Processing Record 11 of Set 7 | los llanos de aridane
# Processing Record 12 of Set 7 | aras
# Processing Record 13 of Set 7 | salekhard
# Processing Record 14 of Set 7 | borama
# City not found. Skipping...
# Processing Record 15 of Set 7 | okha
# Processing Record 16 of Set 7 | porto walter
# Processing Record 17 of Set 7 | margate
# Processing Record 18 of Set 7 | ust-ishim
# Processing Record 19 of Set 7 | giddalur
# Processing Record 20 of Set 7 | roald
# Processing Record 21 of Set 7 | kushima
# Processing Record 22 of Set 7 | ust-tsilma
# Processing Record 23 of Set 7 | chicama
# Processing Record 24 of Set 7 | belmonte
# Processing Record 25 of Set 7 | vanderhoof
# Processing Record 26 of Set 7 | aklavik
# Processing Record 27 of Set 7 | udachnyy
# Processing Record 28 of Set 7 | kyzyl-suu
# Processing Record 29 of Set 7 | berkovica
# Processing Record 30 of Set 7 | champerico
# Processing Record 31 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 32 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 33 of Set 7 | payo
# Processing Record 34 of Set 7 | vestmanna
# Processing Record 35 of Set 7 | vanimo
# Processing Record 36 of Set 7 | rio gallegos
# Processing Record 37 of Set 7 | biak
# Processing Record 38 of Set 7 | san rafael
# Processing Record 39 of Set 7 | bratsk
# Processing Record 40 of Set 7 | gisborne
# Processing Record 41 of Set 7 | porto franco
# Processing Record 42 of Set 7 | severomorsk
# Processing Record 43 of Set 7 | marawi
# Processing Record 44 of Set 7 | ihosy
# Processing Record 45 of Set 7 | arkhangelskoye
# Processing Record 46 of Set 7 | westland
# Processing Record 47 of Set 7 | airai
# Processing Record 48 of Set 7 | grand gaube
# Processing Record 49 of Set 7 | belyy yar
# Processing Record 50 of Set 7 | hasaki
# Processing Record 1 of Set 8 | provideniya
# Processing Record 2 of Set 8 | nantucket
# Processing Record 3 of Set 8 | santarem
# Processing Record 4 of Set 8 | jabinyanah
# Processing Record 5 of Set 8 | ambulu
# Processing Record 6 of Set 8 | comodoro rivadavia
# Processing Record 7 of Set 8 | grand baie
# Processing Record 8 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 9 of Set 8 | abu samrah
# Processing Record 10 of Set 8 | isangel
# Processing Record 11 of Set 8 | saint-philippe
# Processing Record 12 of Set 8 | totness
# Processing Record 13 of Set 8 | yei
# Processing Record 14 of Set 8 | merauke
# Processing Record 15 of Set 8 | fortuna
# Processing Record 16 of Set 8 | hofn
# Processing Record 17 of Set 8 | puerto narino
# Processing Record 18 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 19 of Set 8 | sinnamary
# Processing Record 20 of Set 8 | clyde river
# Processing Record 21 of Set 8 | monchegorsk
# Processing Record 22 of Set 8 | huilong
# Processing Record 23 of Set 8 | marzuq
# Processing Record 24 of Set 8 | springdale
# Processing Record 25 of Set 8 | kabinda
# Processing Record 26 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 8 | olinda
# Processing Record 28 of Set 8 | northam
# Processing Record 29 of Set 8 | mombetsu
# Processing Record 30 of Set 8 | secunda
# Processing Record 31 of Set 8 | nouadhibou
# Processing Record 32 of Set 8 | ancud
# Processing Record 33 of Set 8 | deputatskiy
# Processing Record 34 of Set 8 | basco
# Processing Record 35 of Set 8 | mehamn
# Processing Record 36 of Set 8 | ossora
# Processing Record 37 of Set 8 | inuvik
# Processing Record 38 of Set 8 | kaoma
# Processing Record 39 of Set 8 | namibe
# Processing Record 40 of Set 8 | kurkino
# Processing Record 41 of Set 8 | puerto quijarro
# Processing Record 42 of Set 8 | thinadhoo
# Processing Record 43 of Set 8 | keita
# Processing Record 44 of Set 8 | ankazoabo
# Processing Record 45 of Set 8 | vila velha
# Processing Record 46 of Set 8 | kieta
# Processing Record 47 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 8 | vega baja
# Processing Record 49 of Set 8 | sharjah
# Processing Record 50 of Set 8 | grindavik
# Processing Record 1 of Set 9 | ciudad bolivar
# Processing Record 2 of Set 9 | gorom-gorom
# Processing Record 3 of Set 9 | yomitan
# City not found. Skipping...
# Processing Record 4 of Set 9 | opuwo
# Processing Record 5 of Set 9 | carnarvon
# Processing Record 6 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 7 of Set 9 | mount dora
# Processing Record 8 of Set 9 | gizo
# Processing Record 9 of Set 9 | mitsamiouli
# Processing Record 10 of Set 9 | uenohara
# Processing Record 11 of Set 9 | necochea
# Processing Record 12 of Set 9 | moa
# Processing Record 13 of Set 9 | dikson
# Processing Record 14 of Set 9 | port-cartier
# Processing Record 15 of Set 9 | joshimath
# Processing Record 16 of Set 9 | stephenville
# Processing Record 17 of Set 9 | amapa
# Processing Record 18 of Set 9 | fowa
# Processing Record 19 of Set 9 | nemuro
# Processing Record 20 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 21 of Set 9 | miri
# Processing Record 22 of Set 9 | adrar
# Processing Record 23 of Set 9 | meiktila
# Processing Record 24 of Set 9 | parambu
# Processing Record 25 of Set 9 | eureka
# Processing Record 26 of Set 9 | te anau
# Processing Record 27 of Set 9 | shache
# Processing Record 28 of Set 9 | marsh harbour
# Processing Record 29 of Set 9 | chumikan
# Processing Record 30 of Set 9 | cerrito
# Processing Record 31 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 32 of Set 9 | urengoy
# Processing Record 33 of Set 9 | arlit
# Processing Record 34 of Set 9 | qandala
# Processing Record 35 of Set 9 | jadu
# Processing Record 36 of Set 9 | eastbourne
# Processing Record 37 of Set 9 | mackay
# Processing Record 38 of Set 9 | port augusta
# Processing Record 39 of Set 9 | herat
# Processing Record 40 of Set 9 | san quintin
# Processing Record 41 of Set 9 | bom jesus do itabapoana
# Processing Record 42 of Set 9 | qiongshan
# Processing Record 43 of Set 9 | khvorostyanka
# Processing Record 44 of Set 9 | leshukonskoye
# Processing Record 45 of Set 9 | cayenne
# Processing Record 46 of Set 9 | nanakuli
# Processing Record 47 of Set 9 | peniche
# Processing Record 48 of Set 9 | empalme
# Processing Record 49 of Set 9 | fuerte olimpo
# Processing Record 50 of Set 9 | sisimiut
# Processing Record 1 of Set 10 | ridgetown
# Processing Record 2 of Set 10 | puerto escondido
# Processing Record 3 of Set 10 | greensburg
# Processing Record 4 of Set 10 | zhangjiakou
# Processing Record 5 of Set 10 | faya
# Processing Record 6 of Set 10 | camacha
# Processing Record 7 of Set 10 | nokaneng
# Processing Record 8 of Set 10 | najran
# Processing Record 9 of Set 10 | agucadoura
# Processing Record 10 of Set 10 | uige
# Processing Record 11 of Set 10 | toila
# Processing Record 12 of Set 10 | shakawe
# Processing Record 13 of Set 10 | tazovskiy
# Processing Record 14 of Set 10 | sioux lookout
# Processing Record 15 of Set 10 | ahipara
# Processing Record 16 of Set 10 | vyartsilya
# Processing Record 17 of Set 10 | samastipur
# Processing Record 18 of Set 10 | ponta delgada
# Processing Record 19 of Set 10 | phalaborwa
# Processing Record 20 of Set 10 | jumla
# Processing Record 21 of Set 10 | ambanja
# Processing Record 22 of Set 10 | ballina
# Processing Record 23 of Set 10 | tiarei
# Processing Record 24 of Set 10 | kaeo
# Processing Record 25 of Set 10 | maceio
# Processing Record 26 of Set 10 | lynn haven
# Processing Record 27 of Set 10 | santa cruz
# Processing Record 28 of Set 10 | laguna
# Processing Record 29 of Set 10 | ulladulla
# Processing Record 30 of Set 10 | oksfjord
# Processing Record 31 of Set 10 | srivardhan
# Processing Record 32 of Set 10 | abha
# Processing Record 33 of Set 10 | mount isa
# Processing Record 34 of Set 10 | tuatapere
# Processing Record 35 of Set 10 | buzmeyin
# Processing Record 36 of Set 10 | campbell river
# Processing Record 37 of Set 10 | gigmoto
# Processing Record 38 of Set 10 | santa rosa
# Processing Record 39 of Set 10 | yashkul
# Processing Record 40 of Set 10 | dumas
# Processing Record 41 of Set 10 | okakarara
# Processing Record 42 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 10 | neya
# Processing Record 44 of Set 10 | lohardaga
# Processing Record 45 of Set 10 | klaksvik
# Processing Record 46 of Set 10 | paso de los toros
# Processing Record 47 of Set 10 | kashi
# Processing Record 48 of Set 10 | caravelas
# Processing Record 49 of Set 10 | nizwa
# Processing Record 50 of Set 10 | turukhansk
# Processing Record 1 of Set 11 | cockburn town
# Processing Record 2 of Set 11 | do gonbadan
# Processing Record 3 of Set 11 | mvomero
# Processing Record 4 of Set 11 | liniere
# City not found. Skipping...
# Processing Record 5 of Set 11 | codrington
# Processing Record 6 of Set 11 | the pas
# Processing Record 7 of Set 11 | tezu
# Processing Record 8 of Set 11 | new delhi
# Processing Record 9 of Set 11 | bilibino
# Processing Record 10 of Set 11 | samarai
# Processing Record 11 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 11 | hanyang
# Processing Record 13 of Set 11 | berlevag
# Processing Record 14 of Set 11 | urumqi
# Processing Record 15 of Set 11 | yelan-koleno
# Processing Record 16 of Set 11 | kachug
# Processing Record 17 of Set 11 | eyl
# Processing Record 18 of Set 11 | aksarka
# Processing Record 19 of Set 11 | augustow
# Processing Record 20 of Set 11 | marsala
# Processing Record 21 of Set 11 | floresta
# Processing Record 22 of Set 11 | usinsk
# Processing Record 23 of Set 11 | mikhaylovka
# Processing Record 24 of Set 11 | walvis bay
# Processing Record 25 of Set 11 | gold coast
# Processing Record 26 of Set 11 | lotofaga
# Processing Record 27 of Set 11 | kazanskoye
# Processing Record 28 of Set 11 | jijiga
# Processing Record 29 of Set 11 | muncar
# Processing Record 30 of Set 11 | mitu
# Processing Record 31 of Set 11 | biggar
# Processing Record 32 of Set 11 | magugu
# Processing Record 33 of Set 11 | palmer
# Processing Record 34 of Set 11 | port hawkesbury
# Processing Record 35 of Set 11 | guerrero negro
# Processing Record 36 of Set 11 | atyrau
# Processing Record 37 of Set 11 | robertson
# Processing Record 38 of Set 11 | jonkoping
# Processing Record 39 of Set 11 | pemangkat
# Processing Record 40 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 11 | avera
# Processing Record 42 of Set 11 | stepnogorsk
# Processing Record 43 of Set 11 | wajima
# Processing Record 44 of Set 11 | san carlos de bariloche
# Processing Record 45 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 11 | chipinge
# Processing Record 47 of Set 11 | forio
# Processing Record 48 of Set 11 | buckeye
# Processing Record 49 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 11 | ketchikan
# Processing Record 1 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 12 | south venice
# Processing Record 3 of Set 12 | verkhovazhye
# Processing Record 4 of Set 12 | gedo
# Processing Record 5 of Set 12 | padre bernardo
# Processing Record 6 of Set 12 | qaqortoq
# Processing Record 7 of Set 12 | cabo san lucas
# Processing Record 8 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 9 of Set 12 | teya
# Processing Record 10 of Set 12 | aquiraz
# Processing Record 11 of Set 12 | genhe
# Processing Record 12 of Set 12 | mogadishu
# Processing Record 13 of Set 12 | srednekolymsk
# Processing Record 14 of Set 12 | metro
# Processing Record 15 of Set 12 | carutapera
# Processing Record 16 of Set 12 | saint-georges
# Processing Record 17 of Set 12 | krasnoselkup
# Processing Record 18 of Set 12 | college
# Processing Record 19 of Set 12 | havoysund
# Processing Record 20 of Set 12 | gat
# Processing Record 21 of Set 12 | paoua
# Processing Record 22 of Set 12 | vilyuysk
# Processing Record 23 of Set 12 | owensboro
# Processing Record 24 of Set 12 | mandalgovi
# Processing Record 25 of Set 12 | caldwell
# Processing Record 26 of Set 12 | shahr-e babak
# Processing Record 27 of Set 12 | zasosna
# Processing Record 28 of Set 12 | atambua
# Processing Record 29 of Set 12 | chokwe
# Processing Record 30 of Set 12 | komsomolsk-na-amure
# Processing Record 31 of Set 12 | gazojak
# Processing Record 32 of Set 12 | neiafu
# Processing Record 33 of Set 12 | altay
# Processing Record 34 of Set 12 | mochicahui
# Processing Record 35 of Set 12 | usak
# Processing Record 36 of Set 12 | abu kamal
# Processing Record 37 of Set 12 | brahmapuri
# City not found. Skipping...
# Processing Record 38 of Set 12 | nagato
# Processing Record 39 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 12 | taunggyi
# Processing Record 41 of Set 12 | galesong
# Processing Record 42 of Set 12 | maarianhamina
# Processing Record 43 of Set 12 | puerto penasco
# Processing Record 44 of Set 12 | maldonado
# Processing Record 45 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 46 of Set 12 | ginir
# Processing Record 47 of Set 12 | komarovo
# Processing Record 48 of Set 12 | zolotinka
# City not found. Skipping...
# Processing Record 49 of Set 12 | overath
# Processing Record 50 of Set 12 | bella union
# Processing Record 1 of Set 13 | kodiak
# Processing Record 2 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 13 | magadan
# Processing Record 4 of Set 13 | kuala terengganu
# Processing Record 5 of Set 13 | boa vista
# Processing Record 6 of Set 13 | oranjemund
# Processing Record 7 of Set 13 | porciuncula
# Processing Record 8 of Set 13 | yanam
# Processing Record 9 of Set 13 | san patricio
# Processing Record 10 of Set 13 | ust-ilimsk
# Processing Record 11 of Set 13 | san vicente
# Processing Record 12 of Set 13 | banda aceh
# Processing Record 13 of Set 13 | brownsville
# Processing Record 14 of Set 13 | jacareacanga
# Processing Record 15 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 13 | chaman
# Processing Record 17 of Set 13 | port blair
# Processing Record 18 of Set 13 | ocampo
# Processing Record 19 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 13 | salinopolis
# Processing Record 21 of Set 13 | kavaratti
# Processing Record 22 of Set 13 | port-gentil
# Processing Record 23 of Set 13 | beyneu
# Processing Record 24 of Set 13 | hollins
# Processing Record 25 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 13 | ledyard
# Processing Record 27 of Set 13 | houma
# Processing Record 28 of Set 13 | shibarghan
# City not found. Skipping...
# Processing Record 29 of Set 13 | talara
# Processing Record 30 of Set 13 | tillabery
# City not found. Skipping...
# Processing Record 31 of Set 13 | noumea
# Processing Record 32 of Set 13 | high level
# Processing Record 33 of Set 13 | tazmalt
# Processing Record 34 of Set 13 | taltal
# Processing Record 35 of Set 13 | ust-kulom
# Processing Record 36 of Set 13 | haines junction
# Processing Record 37 of Set 13 | riohacha
# Processing Record 38 of Set 13 | cabedelo
# Processing Record 39 of Set 13 | inhambane
# Processing Record 40 of Set 13 | pingliang
# Processing Record 41 of Set 13 | nizhneivkino
# Processing Record 42 of Set 13 | rabat
# Processing Record 43 of Set 13 | caronport
# Processing Record 44 of Set 13 | pisco
# Processing Record 45 of Set 13 | ikorodu
# Processing Record 46 of Set 13 | arman
# Processing Record 47 of Set 13 | durban
# Processing Record 48 of Set 13 | constitucion
# Processing Record 49 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 13 | ahuimanu
# Processing Record 1 of Set 14 | bandarbeyla
# Processing Record 2 of Set 14 | ermelo
# Processing Record 3 of Set 14 | la asuncion
# Processing Record 4 of Set 14 | waw
# Processing Record 5 of Set 14 | afua
# Processing Record 6 of Set 14 | victor harbor
# Processing Record 7 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 14 | higuey
# City not found. Skipping...
# Processing Record 9 of Set 14 | kisaran
# Processing Record 10 of Set 14 | maamba
# Processing Record 11 of Set 14 | zambezi
# Processing Record 12 of Set 14 | limoges
# Processing Record 13 of Set 14 | saldanha
# Processing Record 14 of Set 14 | okhotsk
# Processing Record 15 of Set 14 | miamisburg
# Processing Record 16 of Set 14 | kimberley
# Processing Record 17 of Set 14 | huarmey
# Processing Record 18 of Set 14 | szubin
# Processing Record 19 of Set 14 | isla mujeres
# Processing Record 20 of Set 14 | buon me thuot
# City not found. Skipping...
# Processing Record 21 of Set 14 | shizunai
# Processing Record 22 of Set 14 | suarez
# Processing Record 23 of Set 14 | dwarahat
# Processing Record 24 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 25 of Set 14 | dillon
# Processing Record 26 of Set 14 | lyuban
# Processing Record 27 of Set 14 | qurayyat
# Processing Record 28 of Set 14 | sokolo
# Processing Record 29 of Set 14 | sandakan
# Processing Record 30 of Set 14 | ibra
# Processing Record 31 of Set 14 | hammond
# Processing Record 32 of Set 14 | usva
# City not found. Skipping...
# Processing Record 33 of Set 14 | zheleznodorozhnyy
# Processing Record 34 of Set 14 | luba
# Processing Record 35 of Set 14 | porto santo
# Processing Record 36 of Set 14 | bedele
# Processing Record 37 of Set 14 | broome
# Processing Record 38 of Set 14 | hirara
# Processing Record 39 of Set 14 | lere
# Processing Record 40 of Set 14 | kamaishi
# Processing Record 41 of Set 14 | acapulco
# Processing Record 42 of Set 14 | hami
# Processing Record 43 of Set 14 | cayhagan
# Processing Record 44 of Set 14 | santa maria
# Processing Record 45 of Set 14 | contamana
# Processing Record 46 of Set 14 | kloulklubed
# Processing Record 47 of Set 14 | mazamari
# Processing Record 48 of Set 14 | sovetskiy
# Processing Record 49 of Set 14 | dongzhen
# Processing Record 50 of Set 14 | nha trang
# Processing Record 1 of Set 15 | saint-augustin
# Processing Record 2 of Set 15 | zaozerne
# Processing Record 3 of Set 15 | portland
# Processing Record 4 of Set 15 | aykhal
# Processing Record 5 of Set 15 | mastung
# Processing Record 6 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 15 | wanaka
# Processing Record 8 of Set 15 | port macquarie
# Processing Record 9 of Set 15 | dakar
# Processing Record 10 of Set 15 | tecpan
# Processing Record 11 of Set 15 | tabou
# Processing Record 12 of Set 15 | evensk
# Processing Record 13 of Set 15 | penzance
# Processing Record 14 of Set 15 | tsabong
# Processing Record 15 of Set 15 | sibolga
# Processing Record 16 of Set 15 | las palmas
# Processing Record 17 of Set 15 | mingaora
# Processing Record 18 of Set 15 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 19 of Set 15 | linxia
# Processing Record 20 of Set 15 | belaya gora
# Processing Record 21 of Set 15 | muroto
# Processing Record 22 of Set 15 | umm lajj
# Processing Record 23 of Set 15 | turayf
# Processing Record 24 of Set 15 | nioro
# Processing Record 25 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 26 of Set 15 | westport
# Processing Record 27 of Set 15 | kastamonu
# Processing Record 28 of Set 15 | ampanihy
# Processing Record 29 of Set 15 | miraflores
# Processing Record 30 of Set 15 | omboue
# Processing Record 31 of Set 15 | kargasok
# Processing Record 32 of Set 15 | kyra
# Processing Record 33 of Set 15 | tianpeng
# Processing Record 34 of Set 15 | kirovohrad
# Processing Record 35 of Set 15 | starogard gdanski
# Processing Record 36 of Set 15 | kindu
# Processing Record 37 of Set 15 | sochi
# Processing Record 38 of Set 15 | fomboni
# Processing Record 39 of Set 15 | raga
# Processing Record 40 of Set 15 | conde
# Processing Record 41 of Set 15 | ilhabela
# Processing Record 42 of Set 15 | ikot ekpene
# Processing Record 43 of Set 15 | zilupe
# Processing Record 44 of Set 15 | paita
# Processing Record 45 of Set 15 | mbaiki
# Processing Record 46 of Set 15 | macomb
# Processing Record 47 of Set 15 | kadoma
# Processing Record 48 of Set 15 | pitea
# Processing Record 49 of Set 15 | dera ghazi khan
# Processing Record 50 of Set 15 | wilmington
# Processing Record 1 of Set 16 | talnakh
# Processing Record 2 of Set 16 | kampot
# Processing Record 3 of Set 16 | maniitsoq
# Processing Record 4 of Set 16 | panjab
# Processing Record 5 of Set 16 | daru
# Processing Record 6 of Set 16 | yining
# Processing Record 7 of Set 16 | pangkalanbuun
# Processing Record 8 of Set 16 | tagusao
# Processing Record 9 of Set 16 | guicheng
# City not found. Skipping...
# Processing Record 10 of Set 16 | amalapuram
# Processing Record 11 of Set 16 | malaya purga
# Processing Record 12 of Set 16 | yirol
# City not found. Skipping...
# Processing Record 13 of Set 16 | anderson
# Processing Record 14 of Set 16 | alihe
# Processing Record 15 of Set 16 | mahad
# Processing Record 16 of Set 16 | quelimane
# Processing Record 17 of Set 16 | salalah
# Processing Record 18 of Set 16 | yuzhnyy
# Processing Record 19 of Set 16 | quatre cocos
# Processing Record 20 of Set 16 | namatanai
# Processing Record 21 of Set 16 | bathsheba
# Processing Record 22 of Set 16 | jizan
# Processing Record 23 of Set 16 | kailua
# Processing Record 24 of Set 16 | kysyl-syr
# Processing Record 25 of Set 16 | puerto suarez
# Processing Record 26 of Set 16 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 27 of Set 16 | requena
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 709

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Mount Gambier -37.8333  140.7667     70.68        43         100
# 1          Vaini -21.2000 -175.2000     84.36        84          40
# 2        Mataura -46.1927  168.8643     75.67        52         100
# 3       Imbituba -28.2400  -48.6703     72.55        90         100
# 4     Ridgecrest  35.6225 -117.6709     46.69        55          39
# 5    Yellowknife  62.4560 -114.3525    -19.44        69          20
# 6         Talgar  43.3027   77.2395      6.96        85          40
# 7        Kitimat  54.0524 -128.6534     26.98        64          44
# 8         Sabang   5.8933   95.3214     80.10        82          61
# 9        Rikitea -23.1203 -134.9692     78.75        72          18
#
#    Wind Speed Country                 Date City_weather
# 0        9.19      AU  2023-01-30 01:50:05       Clouds
# 1        8.05      TO  2023-01-30 01:45:26       Clouds
# 2        5.14      NZ  2023-01-30 01:42:12       Clouds
# 3        4.09      BR  2023-01-30 01:48:22         Rain
# 4       13.00      US  2023-01-30 01:48:11       Clouds
# 5       12.66      CA  2023-01-30 01:39:23       Clouds
# 6        2.24      KZ  2023-01-30 01:50:09         Mist
# 7        1.79      CA  2023-01-30 01:50:10       Clouds
# 8       14.92      ID  2023-01-30 01:50:11       Clouds
# 9        9.06      PF  2023-01-30 01:42:06         Rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'City_weather'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 
                    'Max Temp', 'Humidity', 'Cloudiness',
                    'Wind Speed', 'City_weather']


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0    Mount Gambier      AU  2023-01-30 01:50:05 -37.8333  140.7667     70.68
# 1            Vaini      TO  2023-01-30 01:45:26 -21.2000 -175.2000     84.36
# 2          Mataura      NZ  2023-01-30 01:42:12 -46.1927  168.8643     75.67
# 3         Imbituba      BR  2023-01-30 01:48:22 -28.2400  -48.6703     72.55
# 4       Ridgecrest      US  2023-01-30 01:48:11  35.6225 -117.6709     46.69
# ..             ...     ...                  ...      ...       ...       ...
# 704          Jizan      SA  2023-01-30 02:13:19  17.3333   42.6667     76.48
# 705         Kailua      US  2023-01-30 02:13:20  21.4022 -157.7394     71.58
# 706      Kysyl-Syr      RU  2023-01-30 02:13:21  63.8986  122.7617    -42.21
# 707  Puerto Suarez      BO  2023-01-30 02:13:22 -18.9500  -57.8000     74.59
# 708        Requena      ES  2023-01-30 02:13:23  39.4883   -1.1004     31.51
#
#      Humidity  Cloudiness  Wind Speed City_weather
# 0          43         100        9.19       Clouds
# 1          84          40        8.05       Clouds
# 2          52         100        5.14       Clouds
# 3          90         100        4.09         Rain
# 4          55          39       13.00       Clouds
# ..        ...         ...         ...          ...
# 704        77          17        2.19       Clouds
# 705        94         100        5.01         Rain
# 706        99          99        4.27       Clouds
# 707        86          16        2.57       Clouds
# 708        90          11        3.40       Clouds
#
# [709 rows x 10 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City             object
# Country          object
# Date             object
# Lat             float64
# Lng             float64
# Max Temp        float64
# Humidity          int64
# Cloudiness        int64
# Wind Speed      float64
# City_weather     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
outfile = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(outfile, index_label="City_ID")
